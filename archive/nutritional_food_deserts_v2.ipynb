# %% [markdown]
# # 📊 Visualizing Nutritional Food Deserts: Project Summary & Instructions
#
# ---
#
# ## 🧠 Project Vision
# This project aims to visualize the concept of **nutritional food deserts**, focusing on how access to healthy food varies by location. Inspired by "Banking Desert" studies, the goal is to show how lack of access to nutritious options may correlate with **health outcomes** such as **diabetes** and **high blood pressure**.
#
# ### ✅ Core Objectives:
# 1. Analyze restaurants, convenience stores, and grocery stores to assess nutrition quality of food options.
# 2. Assign each location a **Nutritional Score** (from 0 = poor to 5 = excellent).
# 3. Map access to nutritious food geographically by ZIP code.
# 4. Visualize health outcome data (e.g., diabetes prevalence) by area.
# 5. Study the correlation between poor health outcomes and nutritional access.
#
# ---
#
# ## 🗺️ Planned Visualizations
#
# ### 1. Restaurant Nutritional Score Map
# - **Type**: Geographic scatter or heat map
# - **Color**: Red (0) to Green (5)
# - **Location**: U.S. focus, starting with Georgia and Atlanta
#
# ### 2. Convenience Store Nutritional Score Map
# - Similar layout as restaurants, but focuses on gas stations and corner stores
#
# ### 3. Grocery Store Nutritional Score Map
# - Identifies if nutritious options are more available through grocery chains
#
# ### 4. Health Outcomes Heat Map
# - **Type**: Choropleth / heat map
# - **Metric**: Prevalence of diabetes, high blood pressure
# - **Color**: Blue (low) to Red (high)
#
# ---
#
# ## 🧰 Toolchain for Implementation
# These visualizations will be built first as **PNG mockups**, then implemented in:
# - 📊 Google Sheets
# - 🐍 Python (Plotly)
# - 📈 Power BI
# - 📉 Tableau
#
# ---
#
# ## 🛠️ Instructions for Implementation
#
# ### Step-by-Step:
# 1. Create **dummy data** for ZIP codes, coordinates, and nutrition scores
# 2. Use a **geographic base map** (USA → Georgia → Atlanta)
# 3. Overlay **points** or **choropleths** with color-coded nutrition scores
# 4. Use the **RdYlGn color scale** for accessibility
# 5. Add **ZIP code labels** for context
# 6. Export the map as **PNG** or **SVG**
#
# ---
#
# ## 🎨 Design Notes
# - Use clear titles, legends, and labels
# - Ensure all visual elements are readable and non-overlapping
# - Maps should approximate state/city boundaries for geographic accuracy
# - Consider colorblind-safe palettes
# - Align design with the data literacy level of the audience
#
# # Nutritional Score Formula and Explanation
#
# ## Formula
#
# **Nutritional Score (NS)**:
#
# \[
# NS = \frac{
# w_1 \cdot \text{normalize(calories)} +
# w_2 \cdot \text{normalize(protein\_g)} +
# w_3 \cdot \text{normalize(carbs\_g)} +
# w_4 \cdot \text{normalize(fat\_g)} +
# w_5 \cdot \text{normalize(cholesterol\_mg)} +
# w_6 \cdot \text{normalize(sodium\_mg)}
# }{\text{total\_weight}}
# \]
#
# - `normalize()` scales each raw value to a 0–1 range based on estimated healthy maximums.
# - Weights (`w1` to `w6`) prioritize different nutrients.
# - The final score is between **0 (least healthy)** and **5 (most healthy)**.
#
# ---
#
# ## Explanation
#
# | Nutrient         | Max / Reference Value | Source / Reasoning |
# |------------------|------------------------|---------------------|
# | Calories         | 1000 kcal              | Upper meal limit (CDC, USDA) |
# | Protein (g)      | 50 g                   | Recommended daily intake (~50g; NIH, USDA) |
# | Carbohydrates (g)| 150 g                  | WHO/FAO daily recommendations |
# | Fat (g)          | 70 g                   | Upper daily limit (WHO) |
# | Cholesterol (mg) | 300 mg                 | Upper limit per American Heart Association |
# | Sodium (mg)      | 2400 mg                | Max recommended daily sodium intake (WHO) |

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from IPython.display import display

# %%
img = mpimg.imread("assets/GA_Restaurant_Nutritional_Scatter.png")
plt.imshow(img)
plt.axis("off")  # hide axes
plt.show()

# %%
img = Image.open("assets/GA_Restaurant_Nutritional_Scatter.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1599x1409>

# %%
atl_food_places = [
    {
        "atl_food_place_id":1,
        "title":"Salata",
        "slug":"salata",
        "categories":["healthy","salad"], 
        "lat":"33.775006",
        "lng":" -84.365838",
        "avg_nutrional_score":4,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":2,
        "title":"Gusto! Healthy Bowls & Wraps (West End)",
        "slug":"gusto_healthy_bowls_wraps_west_end",        
        "categories":["fast food","healthy bowls"],
        "lat":"33.7368",
        "lng":"-84.4216",
        "avg_nutrional_score":4.5,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]

    },


    {
        "atl_food_place_id":3,
        "title":"Honeysuckle Gelato (West End)",
        "slug":"honeysuckle",       
        "categories":["ice cream shop"],
        "lat":"33.7368",
        "lng":"-84.4216",
         "avg_nutrional_score":4.6,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":4,
        "title":"Sakera Sake Bar & Bottles (West End)",
        "slug":"sakera",
        "categories":["bar","sake bar"],
        "lat":"33.7368",
        "lng":"-84.4216",
         "avg_nutrional_score":4.9,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":5,
        "title":"Starbucks (Moreland Ave NE)",
        "slug":"starbucks_moreland",
        "categories":["coffee shop"],
        "lat":"33.7599",
        "lng":"-84.3494",
         "avg_nutrional_score":4.2,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":6,
        "title":"Tea'z Social",
        "slug":"teaz_social",
        "categories":["tea house","cafe"],
        "lat":"33.7608",
        "lng":"-84.3499",
        "avg_nutrional_score":4.9,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":7,
        "title":"Mr. Everything Cafe (MLK)",
        "slug":"mr_everything_cafe_mlk",     
        "categories":["cafe","fast casual"],
        "lat":"33.7537,",
        "lng":"-84.4163",
        "avg_nutrional_score":4.3,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":8,
        "title":"Busy Bee Cafe",
        "slug":"busy_bee_cafe",
        "categories":["soul food","restaurant"],
        "lat":"33.7489",
        "lng":"-84.4141",
        "avg_nutrional_score":4.0,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },


    {
        "atl_food_place_id":9,
        "title":"Liquid Wizdom",
        "slug":"liquid_wizdom,
        "categories":["juice shop"],
        "lat":"33.7662",
        "lng":"-84.3477",
         "avg_nutrional_score":4.8,
        "menu_items":[
            {
                "id":1,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":None,
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },

    {
        "atl_food_place_id":10,
        "title":"Hopdoddy Burger Bar",
        "slug":"hopdoddy_burger_bar",
        "categories":["burger restaurant","restaurant"],
        "lat":"33.823",
        "lng":"-84.324",
         "avg_nutrional_score":4.8,
        "menu_items":[
            {
                "id":1,
                "title":"Parmesan Truffle Fries",
                "calories":1240,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":2,
                "title":"Traditional Hand-Cut Fries",
                "calories":830,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":3,
                "title":"Green Chile Queso Fries",
                "calories":1190,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":4,
                "title":"Sweet Potato Fries",
                "calories":1100,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":5,
                "title":"Hot Honey & Sage Sweets Fries",
                "calories":1030,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":6,
                "title":"Crispy Brussel Leaves|Parmesan Truffle Brussel Leaves",
                "calories":840,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":7,
                "title":"Crispy Brussel Leaves|Hot Honey & Sage Brussel Leaves",
                "calories":640,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":8,
                "title":"Burger|The Classic",
                "calories":660,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":9,
                "title":"Burger|Good Night Good Cause",
                "calories":770,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":10,
                "title":"Burger|Magic Shroom",
                "calories":800,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":11,
                "title":"Burger|El Diablo",
                "calories":810,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":12,
                "title":"Burger|Wagyu Mash",
                "calories":1070,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
           {
                "id":13,
                "title":"Burger|Cadillac Wagyu",
                "calories":1140,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":14,
                "title":"Burger|Doddy Melt",
                "calories":1310,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":15,
                "title":"Burger|Buffalo Bill",
                "calories":710,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":16,
                "title":"Burger|Ahi Tuna",
                "calories":600,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":17,
                "title":"Chicken Sandwich|Nashville Hot Chicken",
                "calories":960,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":18,
                "title":"Chicken Sandwich|Crispy Chicken Bacon Ranch",
                "calories":1090,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":19,
                "title":"Chicken Sandwich|Thunderbird",
                "calories":760,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":20,
                "title":"Tossed Tenders",
                "calories":None,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":21,
                "title":"Salad Bowl|Thunder Bowl",
                "calories":750,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":22,
                "title":"Salad Bowl|Diablo Bowl",
                "calories":830,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":23,
                "title":"Salad Bowl|Kale Caesar",
                "calories":680,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":24,
                "title":"Shakes|Tres Leches",
                "calories":640,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":25,
                "title":"Shakes|Double Chocolate Brownie",
                "calories":580,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
            {
                "id":26,
                "title":"Shakes|Bananas Foster",
                "calories":600,
                "protein_g":None,
                "carbs_g":None,
                "fat_g":None,
                "nutrion_score":None
                
            },
        ]
    },



]

# %%
len(atl_food_places)
# Out:
# 10

# %%
for p in atl_food_places:
    print(p['title'])
    print(f"Num of menu items: {len(p['menu_items'])}")
    print()
# Out:
# Salata
# Num of menu items: 3
#
# Gusto! Healthy Bowls & Wraps (West End)
# Num of menu items: 3
#
# Honeysuckle Gelato (West End)
# Num of menu items: 3
#
# Sakera Sake Bar & Bottles (West End)
# Num of menu items: 3
#
# Starbucks (Moreland Ave NE)
# Num of menu items: 3
#
# Tea'z Social
# Num of menu items: 3
#
# Mr. Everything Cafe (MLK)
# Num of menu items: 3
#
# Busy Bee Cafe
# Num of menu items: 3
#
# Liquid Wizdom
# Num of menu items: 3
#
# Hopdoddy Burger Bar
# Num of menu items: 26

# %%
def calculate_nutritional_score(calories, protein_g, carbs_g, fat_g, cholesterol_mg, sodium_mg):
    # Define max/reference values
    max_calories = 1000
    max_protein = 50
    max_carbs = 150
    max_fat = 70
    max_cholesterol = 300
    max_sodium = 2400
    
    # Weights for each component
    w_calories = -1  # Neutral or negative for high calories
    w_protein = 1
    w_carbs = 0.5
    w_fat = -0.5
    w_cholesterol = -1
    w_sodium = -1
    
    # Normalize
    norm_calories = max(0, min(1, calories / max_calories))
    norm_protein = max(0, min(1, protein_g / max_protein))
    norm_carbs = max(0, min(1, carbs_g / max_carbs))
    norm_fat = max(0, min(1, fat_g / max_fat))
    norm_cholesterol = max(0, min(1, cholesterol_mg / max_cholesterol))
    norm_sodium = max(0, min(1, sodium_mg / max_sodium))
    
    # Calculate score
    score = (
        w_calories * norm_calories +
        w_protein * norm_protein +
        w_carbs * norm_carbs +
        w_fat * norm_fat +
        w_cholesterol * norm_cholesterol +
        w_sodium * norm_sodium
    )
    
    # Shift and scale to 0-5
    final_score = max(0, min(5, (score + 5) / 2))
    return final_score
